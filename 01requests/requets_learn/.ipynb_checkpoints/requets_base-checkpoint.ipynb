# %% [markdown]
# # requests的基础语法

# %% [markdown]
# ## 1、发送请求

# %%
import requests

# %%
r = requests.get('https://api.github.com/events')

# %%
r
# Out:
# <Response [200]>

# %% [markdown]
# 现在我们有一个名为r的Response对象，我们可以从这个对象中获取到我们想要的信息。
# 对于requests来说除了上面的get请求之外，还可以向目标网站发送其他的请求。

# %%
r = requests.post('http://httpbin.org/post', data={'key':'value'})
r = requests.put('http://httpbin.org/put', data={'key':'value'})
r = requests.delete('http://httpbin.org/delete')
r = requests.head('http://httpbin.org/get')
r = requests.options('http://httpbin.org/get')

# %% [markdown]
# # 传递URL参数

# %% [markdown]
# 当你为URL的查询字符串传递某种数据时，Requests允许你可以使用params参数，以一个字符串字典来传递这些参数。

# %%
payload = {'key1': 'value1', 'key2': 'value2'}
r = requests.get('http://httpbin.org/get', params=payload)

# %% [markdown]
# 可以通过打印出该URL，可以看见该URL已经被正确的编码

# %%
print(r.url)
# Out:
# http://httpbin.org/get?key1=value1&key2=value2

# %% [markdown]
# **注意：**字典中的值为None的键都不会被添加到URL查询字符串里。

# %%
payload = {'key1': 'value1', 'key2': None}
r = requests.get('http://httpbin.org/get', params=payload)

# %%
print(r.url)
# Out:
# http://httpbin.org/get?key1=value1

# %% [markdown]
# 还可以将列表作为查询字符串传入URL中

# %%
payload = {'key1': 'value1', 'key2': ['value2', 'value3']}
r = requests.get('http://httpbin.org/get', params=payload)

# %%
print(r.url)
# Out:
# http://httpbin.org/get?key1=value1&key2=value2&key2=value3

# %% [markdown]
# # 响应内容

# %% [markdown]
# 我们能够读取服务器的响应内容，需要通过Response.text

# %%
r = requests.get('https://api.github.com/events')
print(r.text)
# Out:
# [{"id":"18672868409","type":"CreateEvent","actor":{"id":51881379,"login":"coldperformer","display_login":"coldperformer","gravatar_id":"","url":"https://api.github.com/users/coldperformer","avatar_url":"https://avatars.githubusercontent.com/u/51881379?"},"repo":{"id":423036227,"name":"coldperformer/taiyo-solution","url":"https://api.github.com/repos/coldperformer/taiyo-solution"},"payload":{"ref":null,"ref_type":"repository","master_branch":"main","description":null,"pusher_type":"user"},"public":true,"created_at":"2021-10-31T02:38:01Z"},{"id":"18672868406","type":"PushEvent","actor":{"id":80723197,"login":"gobugi","display_login":"gobugi","gravatar_id":"","url":"https://api.github.com/users/gobugi","avatar_url":"https://avatars.githubusercontent.com/u/80723197?"},"repo":{"id":418998322,"name":"gobugi/lingoscape","url":"https://api.github.com/repos/gobugi/lingoscape"},"payload":{"push_id":8275556833,"size":2,"distinct_size":1,"ref":"refs/heads/main","head":"0f9d47f798c17c689bafa09f711dea7ec996d9fd","before":"6dce9aac4c90adb2dc1006e0b2ea4fbcda5e5ef1","commits":[{"sha":"6b6af4a5879df8f25bea1ff10eb3718fa188218f","author":{"email":"johnpark1987@gmail.com","name":"johnny"},"message":"favicon","distinct":false,"url":"https://api.github.com/repos/gobugi/lingoscape/commits/6b6af4a5879df8f25bea1ff10eb3718fa188218f"},{"sha":"0f9d47f798c17c689bafa09f711dea7ec996d9fd","author":{"email":"80723197+gobugi@users.noreply.github.com","name":"Johnny Park"},"message":"Merge pull request #76 from gobugi/postcapstone\n\nfavicon","distinct":true,"url":"https://api.github.com/repos/gobugi/lingoscape/commits/0f9d47f798c17c689bafa09f711dea7ec996d9fd"}]},"public":true,"created_at":"2021-10-31T02:38:01Z"},{"id":"18672868400","type":"PushEvent","actor":{"id":8517910,"login":"LombiqBot","display_login":"LombiqBot","gravatar_id":"","url":"https://api.github.com/users/LombiqBot","avatar_url":"https://avatars.githubusercontent.com/u/8517910?"},"repo":{"id":86929735,"name":"Lombiq/Orchard","url":"https://api.github.com/repos/Lombiq/Orchard"},"payload":{"push_id":8275556829,"size":0,"distinct_size":0,"ref":"refs/heads/issue/7467","head":"82585c484ee78d59a5efbbe0c6098f69a6ac4f52","before":"82585c484ee78d59a5efbbe0c6098f69a6ac4f52","commits":[]},"public":true,"created_at":"2021-10-31T02:38:01Z","org":{"id":8158177,"login":"Lombiq","gravatar_id":"","url":"https://api.github.com/orgs/Lombiq","avatar_url":"https://avatars.githubusercontent.com/u/8158177?"}},{"id":"18672868407","type":"CreateEvent","actor":{"id":72578529,"login":"ucarlos1001","display_login":"ucarlos1001","gravatar_id":"","url":"https://api.github.com/users/ucarlos1001","avatar_url":"https://avatars.githubusercontent.com/u/72578529?"},"repo":{"id":423016007,"name":"ucarlos1001/video-preview","url":"https://api.github.com/repos/ucarlos1001/video-preview"},"payload":{"ref":"master","ref_type":"branch","master_branch":"master","description":null,"pusher_type":"user"},"public":true,"created_at":"2021-10-31T02:38:01Z"},{"id":"18672868398","type":"PushEvent","actor":{"id":84486015,"login":"ksore85","display_login":"ksore85","gravatar_id":"","url":"https://api.github.com/users/ksore85","avatar_url":"https://avatars.githubusercontent.com/u/84486015?"},"repo":{"id":419548869,"name":"bcassellius/lovely-librarian","url":"https://api.github.com/repos/bcassellius/lovely-librarian"},"payload":{"push_id":8275556826,"size":1,"distinct_size":0,"ref":"refs/heads/develop","head":"ea4e94ca9bace06e068dec19bf44fc33e906949b","before":"11c0351f015dc3f549f37f22742cdecacb4e312d","commits":[{"sha":"ea4e94ca9bace06e068dec19bf44fc33e906949b","author":{"email":"84486015+ksore85@users.noreply.github.com","name":"ksore85"},"message":"PWA service-worker and index","distinct":false,"url":"https://api.github.com/repos/bcassellius/lovely-librarian/commits/ea4e94ca9bace06e068dec19bf44fc33e906949b"}]},"public":true,"created_at":"2021-10-31T02:38:01Z"},{"id":"18672868405","type":"PushEvent","actor":{"id":8517910,"login":"LombiqBot","displ ...

# %% [markdown]
# Requests会对服务器的响应内容自动解码。
#
# 请求发出之后，Requests会基于HTTP头部对响应的编码做出有根据的推测。当你访问r.text时，Requests会使用其推测的文本编码。
#
# 我们可以找到Requests使用了什么编码，也可以手动改变Requests的编码。

# %%
print(r.encoding)
# Out:
# utf-8

# %%
# r.encoding='ISO-8859-1'

# %%
print(r.encoding)
# Out:
# ISO-8859-1

# %% [markdown]
# 当Requests自动推测的编码不正确的时候，便可以考虑更换encoding的新值。
#
# 可以先通过r.content找到正确编码，再进行更改。

# %% [markdown]
# ##  二进制响应内容

# %%
print(r.content)
# Out:
# b'[{"id":"18672868409","type":"CreateEvent","actor":{"id":51881379,"login":"coldperformer","display_login":"coldperformer","gravatar_id":"","url":"https://api.github.com/users/coldperformer","avatar_url":"https://avatars.githubusercontent.com/u/51881379?"},"repo":{"id":423036227,"name":"coldperformer/taiyo-solution","url":"https://api.github.com/repos/coldperformer/taiyo-solution"},"payload":{"ref":null,"ref_type":"repository","master_branch":"main","description":null,"pusher_type":"user"},"public":true,"created_at":"2021-10-31T02:38:01Z"},{"id":"18672868406","type":"PushEvent","actor":{"id":80723197,"login":"gobugi","display_login":"gobugi","gravatar_id":"","url":"https://api.github.com/users/gobugi","avatar_url":"https://avatars.githubusercontent.com/u/80723197?"},"repo":{"id":418998322,"name":"gobugi/lingoscape","url":"https://api.github.com/repos/gobugi/lingoscape"},"payload":{"push_id":8275556833,"size":2,"distinct_size":1,"ref":"refs/heads/main","head":"0f9d47f798c17c689bafa09f711dea7ec996d9fd","before":"6dce9aac4c90adb2dc1006e0b2ea4fbcda5e5ef1","commits":[{"sha":"6b6af4a5879df8f25bea1ff10eb3718fa188218f","author":{"email":"johnpark1987@gmail.com","name":"johnny"},"message":"favicon","distinct":false,"url":"https://api.github.com/repos/gobugi/lingoscape/commits/6b6af4a5879df8f25bea1ff10eb3718fa188218f"},{"sha":"0f9d47f798c17c689bafa09f711dea7ec996d9fd","author":{"email":"80723197+gobugi@users.noreply.github.com","name":"Johnny Park"},"message":"Merge pull request #76 from gobugi/postcapstone\\n\\nfavicon","distinct":true,"url":"https://api.github.com/repos/gobugi/lingoscape/commits/0f9d47f798c17c689bafa09f711dea7ec996d9fd"}]},"public":true,"created_at":"2021-10-31T02:38:01Z"},{"id":"18672868400","type":"PushEvent","actor":{"id":8517910,"login":"LombiqBot","display_login":"LombiqBot","gravatar_id":"","url":"https://api.github.com/users/LombiqBot","avatar_url":"https://avatars.githubusercontent.com/u/8517910?"},"repo":{"id":86929735,"name":"Lombiq/Orchard","url":"https://api.github.com/repos/Lombiq/Orchard"},"payload":{"push_id":8275556829,"size":0,"distinct_size":0,"ref":"refs/heads/issue/7467","head":"82585c484ee78d59a5efbbe0c6098f69a6ac4f52","before":"82585c484ee78d59a5efbbe0c6098f69a6ac4f52","commits":[]},"public":true,"created_at":"2021-10-31T02:38:01Z","org":{"id":8158177,"login":"Lombiq","gravatar_id":"","url":"https://api.github.com/orgs/Lombiq","avatar_url":"https://avatars.githubusercontent.com/u/8158177?"}},{"id":"18672868407","type":"CreateEvent","actor":{"id":72578529,"login":"ucarlos1001","display_login":"ucarlos1001","gravatar_id":"","url":"https://api.github.com/users/ucarlos1001","avatar_url":"https://avatars.githubusercontent.com/u/72578529?"},"repo":{"id":423016007,"name":"ucarlos1001/video-preview","url":"https://api.github.com/repos/ucarlos1001/video-preview"},"payload":{"ref":"master","ref_type":"branch","master_branch":"master","description":null,"pusher_type":"user"},"public":true,"created_at":"2021-10-31T02:38:01Z"},{"id":"18672868398","type":"PushEvent","actor":{"id":84486015,"login":"ksore85","display_login":"ksore85","gravatar_id":"","url":"https://api.github.com/users/ksore85","avatar_url":"https://avatars.githubusercontent.com/u/84486015?"},"repo":{"id":419548869,"name":"bcassellius/lovely-librarian","url":"https://api.github.com/repos/bcassellius/lovely-librarian"},"payload":{"push_id":8275556826,"size":1,"distinct_size":0,"ref":"refs/heads/develop","head":"ea4e94ca9bace06e068dec19bf44fc33e906949b","before":"11c0351f015dc3f549f37f22742cdecacb4e312d","commits":[{"sha":"ea4e94ca9bace06e068dec19bf44fc33e906949b","author":{"email":"84486015+ksore85@users.noreply.github.com","name":"ksore85"},"message":"PWA service-worker and index","distinct":false,"url":"https://api.github.com/repos/bcassellius/lovely-librarian/commits/ea4e94ca9bace06e068dec19bf44fc33e906949b"}]},"public":true,"created_at":"2021-10-31T02:38:01Z"},{"id":"18672868405","type":"PushEvent","actor":{"id":8517910,"login":"LombiqBot","d ...

# %% [markdown]
# 二进制内容的响应体，一般是用于非文本的请求，一般是音乐、视频以及图片。

# %% [markdown]
# ## JSON响应内容

# %% [markdown]
# Requests中也有一个内置的JSON解码器，助你处理JSON数据

# %%
r = requests.get('https://api.github.com/events')
print(r.json())
# Out:
# [{'id': '18672915070', 'type': 'PushEvent', 'actor': {'id': 541490, 'login': 'morrah', 'display_login': 'morrah', 'gravatar_id': '', 'url': 'https://api.github.com/users/morrah', 'avatar_url': 'https://avatars.githubusercontent.com/u/541490?'}, 'repo': {'id': 224001345, 'name': 'morrah/oro-market', 'url': 'https://api.github.com/repos/morrah/oro-market'}, 'payload': {'push_id': 8275587939, 'size': 1, 'distinct_size': 1, 'ref': 'refs/heads/master', 'head': 'a973130a4aa7cee87c0bfa48946e7957634c95cd', 'before': '045bf1af608ea2436a0b20dca2402e8363cc1bd6', 'commits': [{'sha': 'a973130a4aa7cee87c0bfa48946e7957634c95cd', 'author': {'email': 'morrah@users.noreply.github.com', 'name': 'morrah'}, 'message': 'data update', 'distinct': True, 'url': 'https://api.github.com/repos/morrah/oro-market/commits/a973130a4aa7cee87c0bfa48946e7957634c95cd'}]}, 'public': True, 'created_at': '2021-10-31T02:54:04Z'}, {'id': '18672915066', 'type': 'CreateEvent', 'actor': {'id': 58465170, 'login': 'alvimlops', 'display_login': 'alvimlops', 'gravatar_id': '', 'url': 'https://api.github.com/users/alvimlops', 'avatar_url': 'https://avatars.githubusercontent.com/u/58465170?'}, 'repo': {'id': 423038419, 'name': 'alvimlops/Teste', 'url': 'https://api.github.com/repos/alvimlops/Teste'}, 'payload': {'ref': None, 'ref_type': 'repository', 'master_branch': 'master', 'description': None, 'pusher_type': 'user'}, 'public': True, 'created_at': '2021-10-31T02:54:04Z'}, {'id': '18672915071', 'type': 'CreateEvent', 'actor': {'id': 41898282, 'login': 'github-actions[bot]', 'display_login': 'github-actions', 'gravatar_id': '', 'url': 'https://api.github.com/users/github-actions[bot]', 'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'}, 'repo': {'id': 390204666, 'name': 'ac3rkivacer/bgoole', 'url': 'https://api.github.com/repos/ac3rkivacer/bgoole'}, 'payload': {'ref': 'encryptSrv_3.0.3154.jar', 'ref_type': 'tag', 'master_branch': 'main', 'description': None, 'pusher_type': 'user'}, 'public': True, 'created_at': '2021-10-31T02:54:04Z'}, {'id': '18672915058', 'type': 'ReleaseEvent', 'actor': {'id': 41898282, 'login': 'github-actions[bot]', 'display_login': 'github-actions', 'gravatar_id': '', 'url': 'https://api.github.com/users/github-actions[bot]', 'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'}, 'repo': {'id': 390204666, 'name': 'ac3rkivacer/bgoole', 'url': 'https://api.github.com/repos/ac3rkivacer/bgoole'}, 'payload': {'action': 'published', 'release': {'url': 'https://api.github.com/repos/ac3rkivacer/bgoole/releases/52387256', 'assets_url': 'https://api.github.com/repos/ac3rkivacer/bgoole/releases/52387256/assets', 'upload_url': 'https://uploads.github.com/repos/ac3rkivacer/bgoole/releases/52387256/assets{?name,label}', 'html_url': 'https://github.com/ac3rkivacer/bgoole/releases/tag/encryptSrv_3.0.3154.jar', 'id': 52387256, 'author': {'login': 'github-actions[bot]', 'id': 41898282, 'node_id': 'MDM6Qm90NDE4OTgyODI=', 'avatar_url': 'https://avatars.githubusercontent.com/in/15368?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/github-actions%5Bbot%5D', 'html_url': 'https://github.com/apps/github-actions', 'followers_url': 'https://api.github.com/users/github-actions%5Bbot%5D/followers', 'following_url': 'https://api.github.com/users/github-actions%5Bbot%5D/following{/other_user}', 'gists_url': 'https://api.github.com/users/github-actions%5Bbot%5D/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/github-actions%5Bbot%5D/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/github-actions%5Bbot%5D/subscriptions', 'organizations_url': 'https://api.github.com/users/github-actions%5Bbot%5D/orgs', 'repos_url': 'https://api.github.com/users/github-actions%5Bbot%5D/repos', 'events_url': 'https://api.github.com/users/github-actions%5Bbot%5D/events{/privacy}', 'received_events_url': 'https://api.github.com/users/github-actions%5Bbot%5D/received_events', 'type': 'Bot', 'site_admin': False}, 'node_id': ' ...

# %% [markdown]
# 如果解码失败，就会抛出一个异常。但是有个细节，比如说是http500的错误细节，这种JSON会被解码返回。要检查是否成功，请使用r.raise_for_status或者检查r.status_code和你的期望是否相同。

# %% [markdown]
# ## 定制请求头

# %% [markdown]
# 如果你想要为请求添加HTTP头部，只要简单地传递一个dict给headers参数即可。

# %%
url = 'https://api.github.com'
headers = {'user-agent': 'my-app/0.0.1'}
r = requests.get(url, headers=headers)

# %%
print(r)
# Out:
# <Response [404]>

# %% [markdown]
# ## 更加复杂的post请求

# %% [markdown]
# 通常，需要发送一些编码为表单形式的数据，要实现这个，只需要传递一个dict给data参数。数据字典在发出请求时会自动编码为表单的形式

# %%
payload = {'key1': 'value1', 'key2': 'value2'}
r = requests.post('http://httpbin.org/post', data=payload)

# %%
print(r.text)
# Out:
# {
#   "args": {},
#   "data": "",
#   "files": {},
#   "form": {
#     "key1": "value1",
#     "key2": "value2"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Content-Length": "23",
#     "Content-Type": "application/x-www-form-urlencoded",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.25.1",
#     "X-Amzn-Trace-Id": "Root=1-617e2655-6f05d8dd0ad8041645e2ff56"
#   },
#   "json": null,
#   "origin": "121.33.144.114",
#   "url": "http://httpbin.org/post"
# }

# %% [markdown]
# data还可以接收一个元组，在表单中多个元素使用同一个key的时候是极其有效的。

# %%
payload = (('key1', 'value1'), ('key1', 'value2'))
r = requests.post('http://httpbin.org/post', data=payload)
print(r.text)
# Out:
# {
#   "args": {},
#   "data": "",
#   "files": {},
#   "form": {
#     "key1": [
#       "value1",
#       "value2"
#     ]
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Content-Length": "23",
#     "Content-Type": "application/x-www-form-urlencoded",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.25.1",
#     "X-Amzn-Trace-Id": "Root=1-617e41db-6b44a6b45df9723616b67a99"
#   },
#   "json": null,
#   "origin": "121.33.144.171",
#   "url": "http://httpbin.org/post"
# }

# %% [markdown]
# ## 响应状态码

# %% [markdown]
# 我们可以检测响应状态码的状态

# %%
r = requests.get('http://httpbin.org/get')

# %%
print(r.status_code)
# Out:
# 200

# %% [markdown]
# 为了方便引用，Requests还附带了一个内置的状态码查询对象

# %%
r.status_code == requests.codes.ok
# Out:
# True

# %% [markdown]
# 如果发送一个错误请求（一个4xx客户端错误，或者5xx服务器错误响应），我们可以通过
#
# Response.raise_for_status()来抛出异常

# %%
bad_r = requests.get('http://httpbin.org/status/404')
bad_r.status_code
# Out:
# 404

# %%
bad_r.raise_for_status()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-43-6039039840f0> in <module>
# ----> 1 bad_r.raise_for_status()
#
# E:\ProgramData\Anaconda3\lib\site-packages\requests\models.py in raise_for_status(self)
#     941
#     942         if http_error_msg:
# --> 943             raise HTTPError(http_error_msg, response=self)
#     944
#     945     def close(self):
#
# HTTPError: 404 Client Error: NOT FOUND for url: http://httpbin.org/status/404

# %% [markdown]
# ## 响应头

# %%
r.headers
# Out:
# {'Date': 'Sun, 31 Oct 2021 07:14:07 GMT', 'Content-Type': 'application/json', 'Content-Length': '307', 'Connection': 'keep-alive', 'Server': 'gunicorn/19.9.0', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Credentials': 'true'}

# %% [markdown]
# 这个字典比较特殊，它仅仅是为了HTTP头部而生。
#
# 因此，我们可以使用任意大写的形式来访问这些响应头字段

# %%
r.headers['Content-Type']
# Out:
# 'application/json'

# %%
r.headers.get('content-type')
# Out:
# 'application/json'

# %% [markdown]
# 它还有一个特殊的特点，那就是服务器可以接受同一个header，每次使用不同的值

# %% [markdown]
# ## Cookie

# %% [markdown]
# 如果在某个响应中，包含一些cookie，你可以快速访问它们。

# %% [markdown]
# 想要发送你的cookies到服务器，可以使用cookies参数

# %%
url = 'http://httpbin.org/cookies'
cookies = dict(cookies_are='working')

# %%
r = requests.get(url, cookies=cookies)
r.text
# Out:
# '{\n  "cookies": {\n    "cookies_are": "working"\n  }\n}\n'

# %% [markdown]
# cookie的返回对象为RequestsCookieJar，它的行为和字典类似，但是接口更为完整，适合跨域名、跨路径使用。
#
# 你还可以把CookieJar传到Requests中

# %%
jar = requests.cookies.RequestsCookieJar()
jar.set('tasty_cookie', 'yum', domain='httpbin.org', path='/cookies')
# jar.set('gross_cookie', 'blech', domain='httpbin.org', path='/elsewhere')
url = 'http://httpbin.org/cookies'
r = requests.get(url, cookies=jar)
print(r.text)
# Out:
# {
#   "cookies": {
#     "tasty_cookie": "yum"
#   }
# }

# %% [markdown]
# ## 重定向与请求历史

# %% [markdown]
# 默认情况下，除了HEAD，Requests会自动处理所有的重定向。
#
# 可以使用响应对象的history方法来追踪重定向。它所返回的内容是一个列表
#
#
# 这个对象列表是按照从最老到最新的请求进行排序的

# %%
r = requests.get('http://www.jd.com')

# %%
r.url
# Out:
# 'https://www.jd.com/'

# %%
r.history
# Out:
# [<Response [302]>]

# %% [markdown]
# 如果你使用的是GET、OPTIONS、POST、PUT、PATCH 或者 DELETE，那么你可以通过 allow_redirects 参数禁用重定向处理：

# %%
r = requests.get('http://www.jd.com', allow_redirects=False)

# %%
r.url
# Out:
# 'http://www.jd.com/'

# %%
r.history
# Out:
# []

# %% [markdown]
# 如果你使用的是HEAD，你可以启用重定向

# %%
r = requests.head('http://www.jd.com', allow_redirects=True)
r.url
# Out:
# 'https://www.jd.com/'

# %%
r.history
# Out:
# [<Response [302]>]

# %% [markdown]
# ## 超时

# %% [markdown]
# 你可以告诉requests在经过以timeout参数设定的秒数时间之后停止等待响应。

# %%
r = requests.get('http://www.baidu.com', timeout=0.001)
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# E:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# E:\ProgramData\Anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# E:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#
# E:\ProgramData\Anaconda3\lib\http\client.py in getresponse(self)
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#
# E:\ProgramData\Anaconda3\lib\http\client.py in begin(self)
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#
# E:\ProgramData\Anaconda3\lib\http\client.py in _read_status(self)
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#
# E:\ProgramData\Anaconda3\lib\socket.py in readinto(self, b)
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#
# timeout: timed out
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeoutError                          Traceback (most recent call last)
# E:\ProgramData\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#
# E:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     754
# --> 755             retries = retries.increment(
#     756                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# E:\ProgramData\Anaconda3\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     531             if read is False or not self._is_method_retryable(method):
# --> 532                 raise six.reraise(type(error), error, _stacktrace)
#     533             elif read is not None:
#
# E:\ProgramData\Anaconda3\lib\site-packages\urllib3\packages\six.py in reraise(tp, value, tb)
#     734                 raise value.with_traceback(tb)
# --> 735             raise value
#     736         finally:
#
# E:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#
# E:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
# --> 447             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#     448             raise
#
# E:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _raise_timeout(self, err, url, timeout_value)
#     335         if isinstance(err, SocketTimeout):
# --> 336             raise ReadTimeoutError(
#     337                 self, url, "Read timed out. (read timeout=%s)" % timeout_value
#
# ReadTimeoutError: HTTPConnectionPool(host='www.baidu.com', port=80): Read timed out. (read timeout=0.001)
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeout                               Traceback (most recent call last)
# <ipython-input-81-2c5ff77c4fef> in <module>
# ----> 1 r = requests.get('http://www.baidu.com', timeout=0.001)
#
# E:\ProgramData\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# E:\ProgramData\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# E:\ProgramData\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# E:\ProgramData\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# E:\ProgramData\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     527                 raise SSLError(e, request=request)
#     528             elif isinstance(e, ReadTimeoutError):
# --> 529                 raise ReadTimeout(e, request=request)
#     530             else:
#     531                 raise
#
# ReadTimeout: HTTPConnectionPool(host='www.baidu.com', port=80): Read timed out. (read timeout=0.001)

# %% [markdown]
# timeout仅仅对连接过程有效，与响应的下载体无关

# %% [markdown]
# ## 错误与异常

# %% [markdown]
# 遇到网络问题，（如DNS查询失败、决绝连接等等）时，Requests会抛出一个ConnectionError异常。
#
# 如果是HTTP请求返回了不成功的状态码， Response.raise_for_status() 会抛出一个 HTTPError 异常。
#
# 若请求超时，则抛出一个 Timeout 异常。
#
# 若请求超过了设定的最大重定向次数，则会抛出一个 TooManyRedirects 异常。
#
# 所有Requests显式抛出的异常都继承自 requests.exceptions.RequestException 。
